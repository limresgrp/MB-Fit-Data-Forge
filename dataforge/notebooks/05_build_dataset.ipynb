# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from dataforge.src import DataDict
from dataforge.scripts.build_dataset import build_dataset

DATASET_ROOT =  "/storage_common/angiod/MB-Fit-Data-Forge/POPC/POPC.MULTITEMP"

build_dataset(
    dataset_root = DATASET_ROOT,
    rule_if_file_exists = DataDict.SKIP, # DataDict.OVERWRITE,
    nmer_folder = "trimers", # Specify this if you want to build dataset only for a specific subfolder
    QCHEM_MIN_OUT_ROOT = "/storage_common/angiod/MB-Fit-Data-Forge/POPC/optimized/exp.01/qchem_min_output",
    FIT_POLY_ROOT = "/storage_common/angiod/MB-Fit-Data-Forge/POPC/poly",
    FIT_OPTIM_ROOT = "/storage_common/angiod/MB-Fit-Data-Forge/POPC/optimized/exp.01/data.opt",
)

# script:
# dataforge-build-dataset /storage_common/angiod/MB-Fit-Data-Forge/POPC/POPC.MULTITEMP --nmer_folder trimers/ --QCHEM_MIN_OUT_ROOT "/storage_common/angiod/MB-Fit-Data-Forge/POPC/optimized/exp.01/qchem_min_output" --FIT_POLY_ROOT "/storage_common/angiod/MB-Fit-Data-Forge/POPC/poly" --FIT_OPTIM_ROOT "/storage_common/angiod/MB-Fit-Data-Forge/POPC/optimized/exp.01/data.opt" --rule_if_file_exists 2
