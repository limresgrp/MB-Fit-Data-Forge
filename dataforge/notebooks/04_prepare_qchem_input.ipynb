# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from dataforge.scripts.build_nmers import prepare_qchem_input
from dataforge.src import DataDict
from os.path import join

DATA_ROOT = "/storage_common/angiod/MB-Fit-Data-Forge/POPC/POPC.MULTITEMP/data/"
SUFFIX = "dimers/monomers/C-CHHH"
NMERS_CAPPED_ROOT = join(DATA_ROOT, "xyz_capped/"+SUFFIX)
QCHEM_IN_ROOT     = join(DATA_ROOT, "qchem_input/"+SUFFIX)
QCHEM_MIN_IN_ROOT = join(DATA_ROOT, "qchem_min_input/"+SUFFIX)

prepare_qchem_input(
    NMERS_CAPPED_ROOT,
    QCHEM_IN_ROOT,
    QCHEM_MIN_IN_ROOT,
    DataDict.CHARGES_DICT,
    max_processes=0,
)
